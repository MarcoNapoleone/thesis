# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

output_directory = '/home/marco/DataspellProjects/thesis/output/svm_lin/'

palette = sns.color_palette(["#2176AB", "#F97662", "#FFBF00", "#50C878", "#B284BE"])
sns.set(style="whitegrid", font_scale=1.5)
sns.set_palette(palette)

df = pd.read_csv('../../data/ST002498_z.csv')
df.describe()
# Out:
#               Age      Height      Weight  S-1-pyrroline-5-carboxylate  \
# count  626.000000  626.000000  626.000000                   626.000000
# mean     0.007425    0.010053    0.000285                     0.011043
# std      0.992131    0.967925    0.986467                     1.008773
# min     -3.677439  -10.675699   -5.417313                    -1.998392
# 25%     -0.657136   -0.205737   -0.578473                    -0.708038
# 50%      0.039857    0.016030   -0.106391                    -0.151390
# 75%      0.620684    0.325935    0.483711                     0.558186
# max      2.363167    1.565556    3.876800                     4.389207
#
#        spermidine  1-methylnicotinamide  3-phosphoglycerate  \
# count  626.000000            626.000000          626.000000
# mean    -0.008243             -0.007791           -0.010447
# std      0.964372              0.964043            0.970150
# min     -0.540645             -0.219073           -1.291631
# ...

# %%
from sklearn.metrics import roc_auc_score
import numpy as np

X = df.drop(columns=['Diagnosis'])
y = df['Diagnosis']

# %%
from sklearn.model_selection import StratifiedKFold
#importing SVM linear model
from sklearn.svm import SVC


#choosing the best C value in logspace from 0.0001 to 1000
c_values = np.logspace(-2, 2, 32)
scores = []
cv = StratifiedKFold(n_splits=10, shuffle=True, random_state=42)

for i in c_values:
    kscores = []
    #10-fold cross validation
    for train_index, test_index in cv.split(X, y):
        X_train, X_test = X.iloc[train_index], X.iloc[test_index]
        y_train, y_test = y[train_index], y[test_index]

        svm = SVC(kernel='linear', random_state=42, C=i)
        svm.fit(X_train, y_train)
        y_pred = svm.predict(X_test)
        kscores.append(roc_auc_score(y_test, y_pred))

    scores.append(kscores)

#getting scores distribution for each number of c_values
scores = np.array(scores)
score_mean = np.mean(scores, axis=1)
score_std = np.std(scores, axis=1)
score_25 = np.quantile(scores, 0.25, axis=1)
score_75 = np.quantile(scores, 0.75, axis=1)

# %%
plt.figure(figsize=(10, 10))

# boxplot showing the distribution of the scores using line and markers
plt.plot(c_values, score_mean, color=palette[0], marker='o', markersize=8, linestyle='--', markeredgecolor=palette[0], markerfacecolor='white', linewidth=2)
plt.fill_between(c_values, score_25, score_75, color=palette[0], alpha=0.2)

# y axis limits
plt.ylim(0.2, 0.9)

plt.xscale('log')

# show plot grid
plt.yticks(np.arange(0.2, 0.9, 0.1))
plt.grid(True, linestyle=':', linewidth=1)
plt.xlabel('C')
plt.ylabel('ROC AUC score')
plt.title('SVM-lin ROC AUC score vs C', fontsize=20)
plt.savefig(output_directory + 'svm_lin_c.png', dpi=300)
